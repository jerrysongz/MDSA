# %%
import pandas as pd
import sqlalchemy as sq

# %%
#engine = sq.create_engine('mysql+mysqlconnector://yourusername:yourpassword@datasciencedb.ucalgary.ca/yourusername')
engine = sq.create_engine('mysql+mysqlconnector://zheyu_song:5QFH73NUI@datasciencedb.ucalgary.ca/zheyu_song')
#engine = sq.create_engine('mysql+mysqlconnector://leannewu:604adv3ntur3@datasciencedb.ucalgary.ca/leannewu')

# %%
pets_df = pd.read_csv("Licensed_Pets.csv")
# this could stand to transform the date column to something reasonable
# also the POINT column

pets_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 pets_df = pd.read_csv("Licensed_Pets.csv")
#       2 # this could stand to transform the date column to something reasonable
#       3 # also the POINT column
#       5 pets_df.head()
#
# NameError: name 'pd' is not defined

# %%
pets_df.to_sql("licensed_pets", engine, index=False)
pets_table_df = pd.read_sql_table("licensed_pets", engine)
pets_table_df.head()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/mysql/connector/connection_cext.py:263, in CMySQLConnection._open_connection(self)
#     262 try:
# --> 263     self._cmysql.connect(**cnx_kwargs)
#     264     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Lost connection to MySQL server at 'reading initial communication packet', system error: 0
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3361, in Engine._wrap_pool_connect(self, fn, connection)
#    3360 try:
# -> 3361     return fn()
#    3362 except dialect.dbapi.Error as e:
#
# ...

# %%
# we will get to play here

# %%
engine.dispose()
