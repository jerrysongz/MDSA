# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-1.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd
ENERGY = pd.read_csv("Building_Energy_Benchmarking_-_City_of_Calgary.csv")
ENERGY.head()

import sqlalchemy as sq
sq.__version__
# Out:
# '1.4.40'

# %%
pip install mysql-connector-python-rf
# Out:
# ...
#   Using cached mysql_connector_python_rf-2.2.2-cp310-cp310-linux_x86_64.whl
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
ENERGY.head()
# Out:
#    Property Id Primary Property Type - Self Selected  Number of Buildings  \
# 0      6169481                                Office                    1
# 1      6305956                                Office                    1
# 2      6506773                                Office                    1
# 3      6731628                                Office                    1
# 4      6867796                                Office                    1
#
#    Year Built  Property GFA - Self-Reported (m²)  ENERGY STAR Score  \
# 0        1981                             7770.0               42.0
# 1        1974                             6681.0               80.0
# 2        2008                            14548.0               86.0
# 3        2017                             5223.0               89.0
# 4        1990                              540.0               77.0
#
#    Site Energy Use (GJ)  Weather Normalized Site Energy Use (GJ)  \
# ...

# %%
Yearly = pd.read_csv("yearly.csv")

# %%
#Yearly.to_sql('yearlyhdd', engine )

# %%
engine = sq.create_engine('mysql+mysqlconnector://khushihimanshu_dave:2ZBF74MDV@datasciencedb.ucalgary.ca/khushihimanshu_dave')

# %%
query_table = pd.read_sql_query('DESC energy_bench_data;', engine)
display(query_table)
# Out:
#                                                 Field        Type Null  Key  \
# 0                                               index  bigint(20)  YES  MUL
# 1                                         Property Id  bigint(20)  YES
# 2               Primary Property Type - Self Selected        text  YES
# 3                                 Number of Buildings  bigint(20)  YES
# 4                                          Year Built  bigint(20)  YES
# 5                   Property GFA - Self-Reported (m²)      double  YES
# 6                                   ENERGY STAR Score      double  YES
# 7                                Site Energy Use (GJ)      double  YES
# 8             Weather Normalized Site Energy Use (GJ)      double  YES
# 9                                    Site EUI (GJ/m²)      double  YES
# 10                Weather Normalized Site EUI (GJ/m²)      double  YES
# 11                             Source Energy Use (GJ)      double  YES
# ...

# %%
query_table1 = pd.read_sql_query('DESC yearlyhdd;', engine)
display(query_table1)
# Out:
#                         Field        Type Null  Key Default Extra
# 0                       index  bigint(20)  YES  MUL    None
# 1                Station_Name        text  YES         None
# 2                        Year  bigint(20)  YES         None
# 3             Annual_Air_Temp      double  YES         None
# 4  Annual_Heating_Degree_Days      double  YES         None
# 5  Annual_Cooling_Degree_Days      double  YES         None

# %%
#Q1 = '''ALTER TABLE energy_bench_data DROP COLUMN `District Hot Water Use (GJ)`;'''
#query_table4 = pd.read_sql_query(Q1, engine)
Q2 = '''DESC energy_bench_data;'''
query_table5 = pd.read_sql_query(Q2, engine)
display(query_table5)
# Out:
#                                                 Field        Type Null  Key  \
# 0                                               index  bigint(20)  YES  MUL
# 1                                         Property Id  bigint(20)  YES
# 2               Primary Property Type - Self Selected        text  YES
# 3                                 Number of Buildings  bigint(20)  YES
# 4                                          Year Built  bigint(20)  YES
# 5                   Property GFA - Self-Reported (m²)      double  YES
# 6                                   ENERGY STAR Score      double  YES
# 7                                Site Energy Use (GJ)      double  YES
# 8             Weather Normalized Site Energy Use (GJ)      double  YES
# 9                                    Site EUI (GJ/m²)      double  YES
# 10                Weather Normalized Site EUI (GJ/m²)      double  YES
# 11                             Source Energy Use (GJ)      double  YES
# ...

# %%
Q3= '''SELECT `Primary Property Type - Self Selected`, (ROUND(sum(`ConvertedValues`) * 100.0 / sum(`Site Energy Use (GJ)`), 1)) AS ElecPercent
FROM (SELECT `Primary Property Type - Self Selected`,`Property Id`, `Electricity Use - Grid Purchase (kWh)`,`Site Energy Use (GJ)`,
		ROUND(`Electricity Use - Grid Purchase (kWh)` * 0.0036, 1) AS ConvertedValues FROM energy_bench_data)a 
        WHERE `Primary Property Type - Self Selected` not like 'Other' group by 1;'''


energypercent = pd.read_sql_query(Q3, engine)
display(energypercent)
# Out:
#                Primary Property Type - Self Selected  ElecPercent
# 0                                Distribution Center          3.6
# 1                                       Fire Station         30.6
# 2                     Fitness Center/Health Club/Gym         15.2
# 3                               Heated Swimming Pool         22.7
# 4                                   Ice/Curling Rink         31.8
# 5                                       Indoor Arena         20.7
# 6                                 Mixed Use Property         13.1
# 7                                             Museum         30.4
# 8                         Non-Refrigerated Warehouse         42.4
# 9                                             Office         43.0
# 10                           Other - Public Services         23.3
# 11                                Other - Recreation         23.7
# 12                                   Performing Arts         30.4
# ...

# %%
Q4='''sELECT `Primary Property Type - Self Selected`,(ROUND(sum(`Natural Gas Use (GJ)`) * 100.0 / sum(`Site Energy Use (GJ)`), 1)) AS NGPercent 
FROM energy_bench_data WHERE `Primary Property Type - Self Selected` not like 'Other' group by 1;'''
ngpercent = pd.read_sql_query(Q4, engine)
display(ngpercent)
# Out:
#                Primary Property Type - Self Selected  NGPercent
# 0                                Distribution Center       96.4
# 1                                       Fire Station       69.0
# 2                     Fitness Center/Health Club/Gym       84.5
# 3                               Heated Swimming Pool       77.3
# 4                                   Ice/Curling Rink       68.2
# 5                                       Indoor Arena       79.3
# 6                                 Mixed Use Property       86.9
# 7                                             Museum       69.6
# 8                         Non-Refrigerated Warehouse       50.8
# 9                                             Office       28.2
# 10                           Other - Public Services       76.7
# 11                                Other - Recreation       76.3
# 12                                   Performing Arts       69.6
# 13  Repair Services (Vehicle, Shoe, Locksmith, etc.)       80.8
# ...

# %%
natgas =pd.Series(ngpercent['NGPercent'])
plt.plot(natgas)

# %%
electricity =pd.Series(energypercent['ElecPercent'])
plt.plot(electricity)

# %%
Newdf = pd.merge(ngpercent,energypercent)
print(Newdf)
# Out:
#                Primary Property Type - Self Selected  NGPercent  ElecPercent
# 0                                Distribution Center       96.4          3.6
# 1                                       Fire Station       69.0         30.6
# 2                     Fitness Center/Health Club/Gym       84.5         15.2
# 3                               Heated Swimming Pool       77.3         22.7
# 4                                   Ice/Curling Rink       68.2         31.8
# 5                                       Indoor Arena       79.3         20.7
# 6                                 Mixed Use Property       86.9         13.1
# 7                                             Museum       69.6         30.4
# 8                         Non-Refrigerated Warehouse       50.8         42.4
# 9                                             Office       28.2         43.0
# 10                           Other - Public Services       76.7         23.3
# ...

# %%
Newdf.rename(columns = {'Primary Property Type - Self Selected':'Building_Type'}, inplace = True)

# %%
Newdf
# Out:
#                                        Building_Type  NGPercent  ElecPercent
# 0                                Distribution Center       96.4          3.6
# 1                                       Fire Station       69.0         30.6
# 2                     Fitness Center/Health Club/Gym       84.5         15.2
# 3                               Heated Swimming Pool       77.3         22.7
# 4                                   Ice/Curling Rink       68.2         31.8
# 5                                       Indoor Arena       79.3         20.7
# 6                                 Mixed Use Property       86.9         13.1
# 7                                             Museum       69.6         30.4
# 8                         Non-Refrigerated Warehouse       50.8         42.4
# 9                                             Office       28.2         43.0
# 10                           Other - Public Services       76.7         23.3
# ...

# %%
pip install plo

# %%
import plotly.graph_objects as go
fig = go.Figure(data=[
    go.Bar(name='Natural Gas (kWh)', x=Newdf.Building_Type, y=Newdf.loc[:,"NGPercent"]),
    go.Bar(name='Electricity (kWh)', x=Newdf.Building_Type, y=Newdf.loc[:,"ElecPercent"]),
])

fig.update_layout(barmode='group')
fig.update_layout(legend_title_text = "Energy used",title="Usage of Natural Gas and Electricity between buildings")
fig.update_xaxes(title_text="Building")
fig.update_yaxes(title_text="Energy in kWh")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 import plotly.graph_objects as go
#       2 fig = go.Figure(data=[
#       3     go.Bar(name='Natural Gas (kWh)', x=Newdf.Building_Type, y=Newdf.loc[:,"NGPercent"]),
#       4     go.Bar(name='Electricity (kWh)', x=Newdf.Building_Type, y=Newdf.loc[:,"ElecPercent"]),
#       5 ])
#       7 fig.update_layout(barmode='group')
#
# ModuleNotFoundError: No module named 'plotly'

# %%
#SQL QUERIES

# %% [markdown]
# to find normalised energy, we find total energy per year for all property types.

# %%
#Q5 = '''CREATE TABLE annual_energy1 AS (SELECT SUM(`Site Energy Use (GJ)`) as `Total Energy`, `Year Ending` FROM energy_bench_data GROUP BY `Year Ending`);'''
Q6 = '''SELECT * FROM annual_energy1;'''
EnergyPerYear = pd.read_sql_query(Q6, engine)
display(EnergyPerYear)
# Out:
#    Total Energy  Year Ending
# 0      837892.7         2019
# 1      731769.8         2020
# 2      768821.5         2021

# %%
#Q6='''DELETE FROM yearlyhdd WHERE `Year` = 2018;'''
#deleting = pd.read_sql_query(Q5, engine)
#display(deleting)
Q7='''SELECT * FROM yearlyhdd;'''
show = pd.read_sql_query(Q7, engine)
display(show)
# Out:
#    index      Station_Name  Year  Annual_Air_Temp  Annual_Heating_Degree_Days  \
# 0      1  Calgary Int'L CS  2019         3.320000                      5376.6
# 1      2  Calgary Int'L CS  2020         4.545628                      4974.7
# 2      3  Calgary Int'L CS  2021         4.928493                      4929.9
#
#    Annual_Cooling_Degree_Days
# 0                        18.4
# 1                        50.4
# 2                       158.8

# %%
Q8= '''SELECT annual_energy1.`Total Energy`, yearlyhdd.`Annual_Heating_Degree_Days`, annual_energy1.`Year Ending` FROM annual_energy1, yearlyhdd WHERE yearlyhdd.`Year` = annual_energy1.`Year Ending`;'''
jointTable = pd.read_sql_query(Q8, engine)
display(jointTable)
# Out:
#    Total Energy  Annual_Heating_Degree_Days  Year Ending
# 0      837892.7                      5376.6         2019
# 1      731769.8                      4974.7         2020
# 2      768821.5                      4929.9         2021

# %%
#Q9= '''CREATE TABLE annual_energy_dummy AS (SELECT SUM(`Site Energy Use (GJ)`), `Year Ending` FROM energy_bench_data GROUP BY `Year Ending`);
select * from annual_energy1;

select ROUND(T/A,2) as NormalisedEnergy,ROUND(T,2) as Total_energy,ROUND(A,2) as annual_hdd ,Y
from 
(
SELECT
    annual_energy1.`Total Energy` as T,
    yearlyhdd.`Annual_Heating_Degree_Days` as A,
    annual_energy1.`Year Ending` as Y
FROM
    annual_energy1 inner join yearlyhdd
on yearlyhdd.`Year` = annual_energy1.`Year Ending`)S;'''
#normalised = pd.read_sql_query(Q9, engine)
#display(normalised)
# Out:
#   Input In [24]
#     on yearlyhdd.`Year` = annual_energy1.`Year Ending`)S;'''
#                                                          ^
# SyntaxError: unterminated triple-quoted string literal (detected at line 15)

# %%
var1 =pd.Series(annual_energy['NormalisedEnergy'])
plt.plot(var1)

# %%
Q10='''SELECT AVG(`Site Energy Use (GJ)`) AS 'Avg Annual Energy', `Year Ending` AS 'Year' FROM energy_bench_data GROUP BY `Year Ending`;'''
avgAnnual = pd.read_sql_query(Q10, engine)
display(avgAnnual)
# Out:
#    Avg Annual Energy  Year
# 0        8463.562626  2019
# 1        7391.614141  2020
# 2        7765.873737  2021

# %%
plt.plot(avgAnnual)
