# %%
import pandas as pd
import sqlalchemy as sq
#import mysql.connector
#from pandas.io import sql

# %%
df_w = pd.read_csv("ACISYearlyData-20190101-20210101-PID110037913.csv", encoding= 'unicode_escape')
df_w.head()
display(df_w.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 6 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Station Name                     3 non-null      object
#  1   Date (Local Standard Time)       3 non-null      int64
#  2   Precip. Long Term (mm)           3 non-null      object
#  3   Corn Heat Units (CHU)            3 non-null      object
#  4   Heating Degree Days (18°C) (°C)  3 non-null      object
#  5   Cooling Degree Days (18°C) (°C)  3 non-null      float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 272.0+ bytes
# None

# %%
df_b = pd.read_csv("Building_Energy_Benchmarking_-_City_of_Calgary.csv")
df_b.head()
# Out:
#    Property Id Primary Property Type - Self Selected  Number of Buildings  \
# 0      6169481                                Office                    1
# 1      6305956                                Office                    1
# 2      6506773                                Office                    1
# 3      6731628                                Office                    1
# 4      6867796                                Office                    1
#
#    Year Built  Property GFA - Self-Reported (m²)  ENERGY STAR Score  \
# 0        1981                             7770.0               42.0
# 1        1974                             6681.0               80.0
# 2        2008                            14548.0               86.0
# 3        2017                             5223.0               89.0
# 4        1990                              540.0               77.0
#
#    Site Energy Use (GJ)  Weather Normalized Site Energy Use (GJ)  \
# ...

# %%
df_b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297 entries, 0 to 296
# Data columns (total 23 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   Property Id                                                      297 non-null    int64
#  1   Primary Property Type - Self Selected                            297 non-null    object
#  2   Number of Buildings                                              297 non-null    int64
#  3   Year Built                                                       297 non-null    int64
#  4   Property GFA - Self-Reported (m²)                                297 non-null    float64
#  5   ENERGY STAR Score                                                99 non-null     float64
#  6   Site Energy Use (GJ)                                             297 non-null    float64
# ...

# %%
df = pd.merge(df_b, df_w, left_on='Year Ending', right_on='Date (Local Standard Time)', how='left').drop(['ENERGY STAR Score', 'District Hot Water Use (GJ)','Electricity Use – Generated from Onsite Renewable Systems (kWh)','Station Name','Date (Local Standard Time)'], axis=1)
display(df)

df.info()
# Out:
#      Property Id Primary Property Type - Self Selected  Number of Buildings  \
# 0        6169481                                Office                    1
# 1        6305956                                Office                    1
# 2        6506773                                Office                    1
# 3        6731628                                Office                    1
# 4        6867796                                Office                    1
# ..           ...                                   ...                  ...
# 292     21988624                                Office                    1
# 293     21988625                          Fire Station                    1
# 294     21988627               Other - Public Services                    1
# 295     21988628                          Fire Station                    1
# 296     21988629                          Fire Station                    1
#
# ...

# %%
df.to_csv("603.csv", encoding='utf-8', index=False)

# %%
dfx = pd.read_csv("X_train.csv")
display(dfx)
display(dfx.info())
# Out:
#       carID     brand      model  year transmission  mileage fuelType    tax  \
# 0     13207    hyundi   Santa Fe  2019    Semi-Auto     4223   Diesel  145.0
# 1     17314  vauxhall        GTC  2015       Manual    47870   Diesel  125.0
# 2     12342      audi        RS4  2019    Automatic     5151   Petrol  145.0
# 3     13426        vw   Scirocco  2016    Automatic    20423   Diesel   30.0
# 4     16004     skoda      Scala  2020    Semi-Auto     3569   Petrol  145.0
# ...     ...       ...        ...   ...          ...      ...      ...    ...
# 4955  16898      merc   GL Class  2015    Automatic    24314   Diesel  125.0
# 4956  14416       bmw   6 Series  2017    Automatic    18000   Diesel  145.0
# 4957  15453        vw         CC  2015       Manual    84932   Diesel   30.0
# 4958  14666      audi         A7  2017    Semi-Auto    30150   Diesel  145.0
# 4959  15135      merc        SLK  2014    Automatic    40230   Diesel  150.0
#
#        mpg  engineSize
# ...

# %%
dfy = pd.read_csv("y_train.csv")
display(dfy)
display(dfy.info())
# Out:
#       carID  price
# 0     13207  31995
# 1     17314   7700
# 2     12342  58990
# 3     13426  12999
# 4     16004  16990
# ...     ...    ...
# 4955  16898  17999
# 4956  14416  28900
# 4957  15453   8998
# 4958  14666  23198
# 4959  15135  14900
#
# [4960 rows x 2 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4960 entries, 0 to 4959
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   carID   4960 non-null   int64
#  1   price   4960 non-null   int64
# dtypes: int64(2)
# memory usage: 77.6 KB
# None

# %%
df = pd.merge(dfx, dfy, left_on='carID', right_on='carID', how='left')
display(df)

df.info()
# Out:
#       carID     brand      model  year transmission  mileage fuelType    tax  \
# 0     13207    hyundi   Santa Fe  2019    Semi-Auto     4223   Diesel  145.0
# 1     17314  vauxhall        GTC  2015       Manual    47870   Diesel  125.0
# 2     12342      audi        RS4  2019    Automatic     5151   Petrol  145.0
# 3     13426        vw   Scirocco  2016    Automatic    20423   Diesel   30.0
# 4     16004     skoda      Scala  2020    Semi-Auto     3569   Petrol  145.0
# ...     ...       ...        ...   ...          ...      ...      ...    ...
# 4955  16898      merc   GL Class  2015    Automatic    24314   Diesel  125.0
# 4956  14416       bmw   6 Series  2017    Automatic    18000   Diesel  145.0
# 4957  15453        vw         CC  2015       Manual    84932   Diesel   30.0
# 4958  14666      audi         A7  2017    Semi-Auto    30150   Diesel  145.0
# 4959  15135      merc        SLK  2014    Automatic    40230   Diesel  150.0
#
#        mpg  engineSize  price
# ...

# %%
df['transmission'].nunique()
# Out:
# 4

# %%
df.dropna() 
display(df)

df.info()
# Out:
#       carID     brand      model  year transmission  mileage fuelType    tax  \
# 0     13207    hyundi   Santa Fe  2019    Semi-Auto     4223   Diesel  145.0
# 1     17314  vauxhall        GTC  2015       Manual    47870   Diesel  125.0
# 2     12342      audi        RS4  2019    Automatic     5151   Petrol  145.0
# 3     13426        vw   Scirocco  2016    Automatic    20423   Diesel   30.0
# 4     16004     skoda      Scala  2020    Semi-Auto     3569   Petrol  145.0
# ...     ...       ...        ...   ...          ...      ...      ...    ...
# 4955  16898      merc   GL Class  2015    Automatic    24314   Diesel  125.0
# 4956  14416       bmw   6 Series  2017    Automatic    18000   Diesel  145.0
# 4957  15453        vw         CC  2015       Manual    84932   Diesel   30.0
# 4958  14666      audi         A7  2017    Semi-Auto    30150   Diesel  145.0
# 4959  15135      merc        SLK  2014    Automatic    40230   Diesel  150.0
#
#        mpg  engineSize  price
# ...

# %%
df.to_csv("car.csv", encoding='utf-8', index=False)
